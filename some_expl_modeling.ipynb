# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

for path, dirs, files in os.walk("/content/drive/MyDrive"):
    print(path)
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/rdfia
# /content/drive/MyDrive/rdfia/sift
# /content/drive/MyDrive/rdfia/sift/CALsuburb
# /content/drive/MyDrive/rdfia/sift/MITcoast
# /content/drive/MyDrive/rdfia/sift/MITforest
# /content/drive/MyDrive/rdfia/sift/MIThighway
# /content/drive/MyDrive/rdfia/sift/MITinsidecity
# /content/drive/MyDrive/rdfia/sift/MITmountain
# /content/drive/MyDrive/rdfia/sift/MITopencountry
# /content/drive/MyDrive/rdfia/sift/MITstreet
# /content/drive/MyDrive/rdfia/sift/MITtallbuilding
# /content/drive/MyDrive/rdfia/sift/PARoffice
# /content/drive/MyDrive/rdfia/sift/bedroom
# /content/drive/MyDrive/rdfia/sift/industrial
# /content/drive/MyDrive/rdfia/sift/kitchen
# /content/drive/MyDrive/rdfia/sift/livingroom
# /content/drive/MyDrive/rdfia/sift/store
# /content/drive/MyDrive/rdfia/kmeans
# /content/drive/MyDrive/Assignment1
# /content/drive/MyDrive/Assignment1/.idea
# /content/drive/MyDrive/Assignment1/.idea/inspectionProfiles
# /content/drive/MyDrive/ANN (1)
# /content/drive/MyDrive/ANN (1)/LAB1
# /content/drive/MyDrive/ANN (1)/LAB1/Iris_Feedforward
# /content/drive/MyDrive/ANN (1)/LAB1/Iris_Feedforward/variables
# /content/drive/MyDrive/ANN (1)/LAB1/Iris_Feedforward/assets
# /content/drive/MyDrive/RDFIA notebooks
# /content/drive/MyDrive/RDFIA notebooks/TP2
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/Colab Notebooks/HW2_ANN
# /content/drive/MyDrive/Colab Notebooks/HW2_ANN/training_dataset
# /content/drive/MyDrive/ANN
# /content/drive/MyDrive/ANN/Model_with_augmentation
# /content/drive/MyDrive/ANN/Model_with_augmentation/variables
# /content/drive/MyDrive/ANN/Model_with_augmentation/assets
# /content/drive/MyDrive/ANN/TransferLearningModel
# /content/drive/MyDrive/ANN/TransferLearningModel/variables
# /content/drive/MyDrive/ANN/TransferLearningModel/assets
# /content/drive/MyDrive/foto laurea Giulia
# /content/drive/MyDrive/Cristina
# /content/drive/MyDrive/Cristina/__pycache__
# /content/drive/MyDrive/foto tramonto io e giulia

# %%
import os

base_path = "/content/drive/MyDrive/data_genhack"  # adjust name
for root, dirs, files in os.walk(base_path):
    print(root)
    for f in files:
        print("   ", f)
# Out:
# /content/drive/MyDrive/data_genhack
# /content/drive/MyDrive/data_genhack/main
#     ECA_blend_tx.zip
#     gadm_410_europe.gpkg
#     read-era5-netcdf_v2.ipynb
#     GenHack - Kayrros data User Guide.gdoc
# /content/drive/MyDrive/data_genhack/main/derived-era5-land-daily-statistics
#     2021_10m_v_component_of_wind_daily_mean.nc
#     2021_10m_u_component_of_wind_daily_mean.nc
#     2020_10m_v_component_of_wind_daily_mean.nc
#     2020_2m_temperature_daily_maximum.nc
#     2020_10m_u_component_of_wind_daily_mean.nc
#     2022_2m_temperature_daily_maximum.nc
#     2022_10m_v_component_of_wind_daily_mean.nc
#     2023_10m_u_component_of_wind_daily_mean.nc
#     2022_10m_u_component_of_wind_daily_mean.nc
#     2021_2m_temperature_daily_maximum.nc
#     2023_2m_temperature_daily_maximum.nc
#     2025_10m_u_component_of_wind_daily_mean.nc
#     2024_2m_temperature_daily_maximum.nc
#     2024_10m_u_component_of_wind_daily_mean.nc
#     2025_2m_temperature_daily_maximum.nc
#     2023_10m_v_component_of_wind_daily_mean.nc
#     2025_10m_v_component_of_wind_daily_mean.nc
#     2024_10m_v_component_of_wind_daily_mean.nc
#     2025_total_precipitation_daily_mean.nc
#     2021_total_precipitation_daily_mean.nc
#     2020_total_precipitation_daily_mean.nc
#     2024_total_precipitation_daily_mean.nc
#     2022_total_precipitation_daily_mean.nc
#     2023_total_precipitation_daily_mean.nc
# /content/drive/MyDrive/data_genhack/main/sentinel2_ndvi
#     ndvi_2019-12-01_2020-03-01.tif
#     ndvi_2020-03-01_2020-06-01.tif
#     ndvi_2020-06-01_2020-09-01.tif
#     ndvi_2020-09-01_2020-12-01.tif
#     ndvi_2020-12-01_2021-03-01.tif
#     ndvi_2021-03-01_2021-06-01.tif
#     ndvi_2021-09-01_2021-12-01.tif
#     ndvi_2021-12-01_2022-03-01.tif
#     ndvi_2021-06-01_2021-09-01.tif
#     ndvi_2022-06-01_2022-09-01.tif
#     ndvi_2022-03-01_2022-06-01.tif
#     ndvi_2022-09-01_2022-12-01.tif
#     ndvi_2022-12-01_2023-03-01.tif
#     ndvi_2023-03-01_2023-06-01.tif
#     ndvi_2023-09-01_2023-12-01.tif
#     ndvi_2023-06-01_2023-09-01.tif
# /content/drive/MyDrive/data_genhack/outdated
#     gadm_410.gpkg
# /content/drive/MyDrive/data_genhack/outdated/derived-era5-single-levels-daily-statistics
#     2015_2m_temperature_daily_maximum.nc
#     2015_total_precipitation_daily_mean.nc
#     2015_10m_v_component_of_wind_daily_mean.nc
#     2015_10m_u_component_of_wind_daily_mean.nc
#     2016_10m_u_component_of_wind_daily_mean.nc
#     2017_10m_u_component_of_wind_daily_mean.nc
#     2016_total_precipitation_daily_mean.nc
#     2016_10m_v_component_of_wind_daily_mean.nc
#     2016_2m_temperature_daily_maximum.nc
#     2017_2m_temperature_daily_maximum.nc
#     2018_10m_v_component_of_wind_daily_mean.nc
#     2018_10m_u_component_of_wind_daily_mean.nc
#     2017_10m_v_component_of_wind_daily_mean.nc
#     2017_total_precipitation_daily_mean.nc
#     2018_2m_temperature_daily_maximum.nc
#     2019_10m_u_component_of_wind_daily_mean.nc
#     2019_10m_v_component_of_wind_daily_mean.nc
#     2019_2m_temperature_daily_maximum.nc
#     2019_total_precipitation_daily_mean.nc
#     2018_total_precipitation_daily_mean.nc
#     2020_2m_temperature_daily_maximum.nc
#     2020_10m_v_component_of_wind_daily_mean.nc
#     2021_10m_v_component_of_wind_daily_mean.nc
#     2021_10m_u_component_of_wind_daily_mean.nc
#     2021_2m_temperature_daily_maximum.nc
#     2020_10m_u_component_of_wind_daily_mean.nc
#     2021_total_precipitation_daily_mean.nc
#     2022_10m_u_component_of_wind_daily_mean.nc
#     2022_2m_temperature_daily_maximum.nc
#     2023_10m_u_component_of_wind_daily_mean.nc
#     2022_10m_v_component_of_wind_daily_mean.nc
#     2024_10m_u_component_of_wind_daily_mean.nc
#     2023_10m_v_component_of_wind_daily_mean.nc
#     2024_2m_temperature_daily_maximum.nc
#     2023_2m_temperature_daily_maximum.nc
#     2024_10m_v_component_of_wind_daily_mean.nc
#     2023_total_precipitation_daily_mean.nc
#     2025_10m_v_component_of_wind_daily_mean.nc
#     2025_2m_temperature_daily_maximum.nc
#     2024_total_precipitation_daily_mean.nc
#     2020_total_precipitation_daily_mean.nc
#     2025_total_precipitation_daily_mean.nc
#     2025_10m_u_component_of_wind_daily_mean.nc
#     2022_total_precipitation_daily_mean.nc
# /content/drive/MyDrive/data_genhack/outdated/sentinel3-olci-ndvi
#     SENTINEL3_OLCI_Europe_NDVI_20200701.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200711.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200721.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200801.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200811.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200821.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200901.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200911.tif
#     SENTINEL3_OLCI_Europe_NDVI_20200921.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201001.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201011.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201021.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20201221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210301.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210311.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210321.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210401.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210411.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210421.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210501.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210511.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210521.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210601.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210611.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210621.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210701.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210711.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210721.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210801.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210811.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210821.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210901.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210911.tif
#     SENTINEL3_OLCI_Europe_NDVI_20210921.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211001.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211011.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211021.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20211221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220301.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220311.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220321.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220401.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220411.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220421.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220501.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220511.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220521.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220601.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220611.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220621.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220701.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220711.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220721.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220801.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220811.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220821.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220901.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220911.tif
#     SENTINEL3_OLCI_Europe_NDVI_20220921.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221001.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221011.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221021.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20221221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230301.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230311.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230321.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230401.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230411.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230421.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230501.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230511.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230521.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230601.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230611.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230621.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230701.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230711.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230721.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230801.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230811.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230821.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230901.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230911.tif
#     SENTINEL3_OLCI_Europe_NDVI_20230921.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231001.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231011.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231021.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20231221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240101.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240111.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240121.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240201.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240211.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240221.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240301.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240311.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240321.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240401.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240411.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240421.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240501.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240511.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240521.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240601.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240611.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240621.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240701.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240711.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240721.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240801.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240811.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240821.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240901.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240911.tif
#     SENTINEL3_OLCI_Europe_NDVI_20240921.tif
#     SENTINEL3_OLCI_Europe_NDVI_20241001.tif
#     SENTINEL3_OLCI_Europe_NDVI_20241011.tif
#     SENTINEL3_OLCI_Europe_NDVI_20241021.tif
# /content/drive/MyDrive/data_genhack/edited
#     Copia di gadm_410.gpkg
#     read-era5-netcdf_v0.html
#     Copie de read-era5-netcdf_v2.ipynb
#     Copia de read-era5-netcdf_v0.ipynb
#     read-era5-netcdf_v1.ipynb
#     Copy of gadm_410.gpkg
#     read-era5-netcdf_v0.ipynb
#     Copie de Copia de read-era5-netcdf_v1.ipynb
#     gadm_410_europe.gpkg（副本）
#     Copia de read-era5-netcdf_v1.ipynb
#     date_timestamp.txt
#     data!.ipynb
#     read-era5-netcdf_v2.ipynb
#     Copia di read-era5-netcdf_v2.ipynb
#     Copy of read-era5-netcdf_v2.ipynb
#     Copia de read-era5-netcdf_v2.ipynb
# /content/drive/MyDrive/data_genhack/edited/GenHackData
# /content/drive/MyDrive/data_genhack/edited/.AU.30ovU.nosync
# /content/drive/MyDrive/data_genhack/edited/ECA_blend_tx_broken
# /content/drive/MyDrive/data_genhack/edited/trash_zone
# /content/drive/MyDrive/data_genhack/edited/~.
# /content/drive/MyDrive/data_genhack/edited/ECA_blend_tx
#     stations.txt
#     TX_STAID004563.txt

# %%
import os
import zipfile
import numpy as np
import pandas as pd
import xarray as xr
import rasterio
from rasterio.warp import transform
import geopandas as gpd
import matplotlib.pyplot as plt

base_main = "/content/drive/MyDrive/data_genhack/main"
era5_dir = os.path.join(base_main, "derived-era5-land-daily-statistics")
ndvi_dir = os.path.join(base_main, "sentinel2_ndvi")
eca_zip = os.path.join(base_main, "ECA_blend_tx.zip")
gadm_path = os.path.join(base_main, "gadm_410_europe.gpkg")  # per confini, se serve

# %% [markdown]
# Reading stations metadata

# %%
# path sul drive dove sta lo zip
eca_zip = "/content/drive/MyDrive/data_genhack/main/ECA_blend_tx.zip"

# directory locale (scrivibile)
eca_dir = "/content/eca_unzip"
os.makedirs(eca_dir, exist_ok=True)

with zipfile.ZipFile(eca_zip, 'r') as zf:
    zf.extractall(eca_dir)

print(os.listdir(eca_dir)[:10])
# Out:
# ['TX_STAID025690.txt', 'TX_STAID002971.txt', 'TX_STAID024778.txt', 'TX_STAID000951.txt', 'TX_STAID024731.txt', 'TX_STAID027829.txt', 'TX_STAID025836.txt', 'TX_STAID025612.txt', 'TX_STAID024834.txt', 'TX_STAID018055.txt']

# %%
stations_path = os.path.join(eca_dir, "stations.txt")

# trova il numero di riga dove inizia la tabella (cerca "STAID")
header_line = None
with open(stations_path, "r") as f:
    for i, line in enumerate(f):
        if line.strip().startswith("STAID"):
            header_line = i
            break

print("Header line at:", header_line)
# Out:
# Header line at: 17

# %%
# leggi solo la riga di header (quella con STAID,STANAME,...)
with open(stations_path, "r") as f:
    for i, line in enumerate(f):
        if i == header_line:
            header_text = line.strip()
            break

print("Header text:", header_text)

colnames = [c.strip() for c in header_text.split(",")]
print("Column names:", colnames)
# Out:
# Header text: STAID,STANAME                                 ,CN,      LAT,       LON,HGHT
# Column names: ['STAID', 'STANAME', 'CN', 'LAT', 'LON', 'HGHT']

# %%
import pandas as pd

stations = pd.read_csv(
    stations_path,
    skiprows=header_line + 1,
    header=None,
    names=colnames,
    engine="python"
)

stations.head()
# Out:
#    STAID                                       STANAME    CN        LAT  \
# 0      1  VAEXJOE                                       SE    +56:52:00
# 1      2  FALUN                                         SE    +60:37:00
# 2      3  STENSELE                                      SE    +65:04:00
# 3      4  LINKOEPING                                    SE    +58:24:00
# 4      5  LINKOEPING-MALMSLAETT                         SE    +58:24:00
#
#           LON  HGHT
# 0  +014:48:00   166
# 1  +015:37:00   160
# 2  +017:09:59   325
# 3  +015:31:59    93
# 4  +015:31:59    93

# %%
stations = stations.rename(columns={
    "STAID": "station_id",
    "STANAME": "name",
    "LAT": "lat",
    "LON": "lon",
    "HGHT": "alt"
})
stations["station_id"] = stations["station_id"].astype(str).str.zfill(6)
stations.head()
# Out:
#   station_id                                          name    CN        lat  \
# 0     000001  VAEXJOE                                       SE    +56:52:00
# 1     000002  FALUN                                         SE    +60:37:00
# 2     000003  STENSELE                                      SE    +65:04:00
# 3     000004  LINKOEPING                                    SE    +58:24:00
# 4     000005  LINKOEPING-MALMSLAETT                         SE    +58:24:00
#
#           lon  alt
# 0  +014:48:00  166
# 1  +015:37:00  160
# 2  +017:09:59  325
# 3  +015:31:59   93
# 4  +015:31:59   93

# %% [markdown]
# Helper functions for loading ERA5 Tmax (2m temperature daily max)

# %%
def load_era5_tmax_year(year: int) -> xr.Dataset:
    path = os.path.join(
        era5_dir,
        f"{year}_2m_temperature_daily_maximum.nc"
    )
    ds = xr.open_dataset(path)
    # di solito la variabile si chiama 'mx2t' o simile: controlla
    print(ds)  # una volta per capire i nomi
    return ds

# %%
era5_sample = load_era5_tmax_year(2020)
var_name = [v for v in era5_sample.data_vars][0]
print("ERA5 var:", var_name)
# Out:
# <xarray.Dataset> Size: 338MB
# Dimensions:     (valid_time: 366, latitude: 350, longitude: 660)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 3kB 2020-01-01 ... 2020-12-31
#   * latitude    (latitude) float64 3kB 69.9 69.8 69.7 69.6 ... 35.2 35.1 35.0
#   * longitude   (longitude) float64 5kB -25.0 -24.9 -24.8 ... 40.7 40.8 40.9
#     number      int64 8B ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 338MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-10-03T16:43 GRIB to CDM+CF via cfgrib-0.9.1...
# ERA5 var: t2m

# %%
def extract_era5_at_point(ds: xr.Dataset, lat, lon):
    """Restituisce una Series (indexed by time) con Tmax ERA5 per il punto lat/lon più vicino."""
    # sel con nearest
    point = ds[var_name].sel(latitude=lat, longitude=lon, method="nearest")
    # convertiamo a pandas.Series
    s = point.to_series()
    s.name = "t_era5"
    return s

# %% [markdown]
# Helper functions: NDVI Sentinel-2 for one station

# %%
import datetime as dt
from dateutil.parser import parse as parse_date

# costruiamo un indice: (start_date, end_date, filepath)
ndvi_files = []
for fname in sorted(os.listdir(ndvi_dir)):
    if fname.endswith(".tif"):
        _, start_str, end_str = fname.replace(".tif", "").split("_")
        start = pd.to_datetime(start_str)
        end = pd.to_datetime(end_str)
        ndvi_files.append({
            "start": start,
            "end": end,
            "path": os.path.join(ndvi_dir, fname)
        })
ndvi_index = pd.DataFrame(ndvi_files)
ndvi_index.head()
# Out:
#        start        end                                               path
# 0 2019-12-01 2020-03-01  /content/drive/MyDrive/data_genhack/main/senti...
# 1 2020-03-01 2020-06-01  /content/drive/MyDrive/data_genhack/main/senti...
# 2 2020-06-01 2020-09-01  /content/drive/MyDrive/data_genhack/main/senti...
# 3 2020-09-01 2020-12-01  /content/drive/MyDrive/data_genhack/main/senti...
# 4 2020-12-01 2021-03-01  /content/drive/MyDrive/data_genhack/main/senti...

# %%
def find_ndvi_file(date: pd.Timestamp):
    row = ndvi_index[(ndvi_index["start"] <= date) & (ndvi_index["end"] > date)]
    if row.empty:
        return None
    return row.iloc[0]["path"]

# %%
from rasterio.warp import transform

def sample_ndvi_at_point(date: pd.Timestamp, lat: float, lon: float):
    tif_path = find_ndvi_file(date)
    if tif_path is None:
        return np.nan

    with rasterio.open(tif_path) as src:
        # coordinate nell'SRS del raster
        if src.crs.to_epsg() != 4326:
            xs, ys = transform("EPSG:4326", src.crs, [lon], [lat])
            x, y = xs[0], ys[0]
        else:
            x, y = lon, lat
        row, col = src.index(x, y)
        ndvi_val = src.read(1)[row, col]
        # spesso NDVI è scalato (es. int16 0–10000), controlla dalla doc
        return float(ndvi_val)

# %% [markdown]
# Building dataframe master for some stations/years

# %%
import os

# trova un file TX per una qualsiasi stazione
for f in os.listdir(eca_dir):
    if f.startswith("TX_STAID") and f.endswith(".txt"):
        example_tx = os.path.join(eca_dir, f)
        print("Using example:", example_tx)
        break

# stampa le prime righe
with open(example_tx) as f:
    for i in range(20):
        print(f.readline().rstrip())
# Out:
# Using example: /content/eca_unzip/TX_STAID025690.txt
# EUROPEAN CLIMATE ASSESSMENT & DATASET (ECA&D), file created on: 16-09-2025
# THESE DATA CAN BE USED FOR NON-COMMERCIAL RESEARCH AND EDUCATION PROVIDED THAT THE FOLLOWING SOURCE IS ACKNOWLEDGED:
#
# Klein Tank, A.M.G. and Coauthors, 2002. Daily dataset of 20th-century surface
# air temperature and precipitation series for the European Climate Assessment.
# Int. J. of Climatol., 22, 1441-1453.
# Data and metadata available at http://www.ecad.eu
#
# FILE FORMAT (MISSING VALUE CODE = -9999):
#
# 01-06 STAID: Station identifier
# 08-13 SOUID: Source identifier
# 15-22 DATE : Date YYYYMMDD
# 24-28 TX   : Maximum temperature in 0.1 &#176;C
# 30-34 Q_TX : quality code for TX (0='valid'; 1='suspect'; 9='missing')
#
# This is the blended series of station VALLERMOSA, ITALY (STAID: 25690)
# Blended and updated with sources:148095
# See files sources.txt and stations.txt for more info.

# %%
import pandas as pd

def load_station_tmax_series(station_id: str):
    """
    Legge un file TX_STAIDxxxxxx.txt dell’ECA&D
    e restituisce un DataFrame:
        date | t_station
    dove t_station è in °C.
    """
    # Nome del file dentro la cartella estratta
    fname = f"TX_STAID{station_id}.txt"
    fpath = os.path.join(eca_dir, fname)

    if not os.path.exists(fpath):
        raise FileNotFoundError(f"File not found: {fpath}")

    # Trova dove inizia la parte tabellare (la prima riga che comincia con un numero)
    start_line = None
    with open(fpath, "r") as f:
        for i, line in enumerate(f):
            if line[:6].strip().isdigit():   # STAID è nei caratteri 1–6
                start_line = i
                break

    if start_line is None:
        raise ValueError("No data section found in " + fpath)

    # Leggi la tabella con colspecs
    df = pd.read_fwf(
        fpath,
        skiprows=start_line,
        colspecs=[(0,6), (7,13), (14,22), (23,28), (29,34)],
        names=["STAID", "SOUID", "DATE", "TX", "Q_TX"]
    )

    # Converti date
    df["DATE"] = pd.to_datetime(df["DATE"], format="%Y%m%d", errors="coerce")

    # Converti temperatura (da decimi di °C → °C)
    df["t_station"] = df["TX"] / 10.0

    # filtra valori mancanti
    df = df[df["t_station"] > -999]   # -999.9 → missing

    # Teniamo solo le colonne che ci servono
    df = df[["DATE", "t_station"]].rename(columns={"DATE": "date"})

    return df

# %%
test = load_station_tmax_series("018510")
test.head()
# Out:
#           date  t_station
# 13  2014-04-14        0.9
# 640 2016-01-01       -1.6
# 641 2016-01-02       -3.5
# 642 2016-01-03      -11.0
# 643 2016-01-04      -13.6

# %%
print("Stations table shape:", stations.shape)
print(stations.head())
print(stations.columns)
# Out:
# Stations table shape: (8568, 6)
#   station_id                                          name    CN        lat  \
# 0     000001  VAEXJOE                                       SE    +56:52:00
# 1     000002  FALUN                                         SE    +60:37:00
# 2     000003  STENSELE                                      SE    +65:04:00
# 3     000004  LINKOEPING                                    SE    +58:24:00
# 4     000005  LINKOEPING-MALMSLAETT                         SE    +58:24:00
#
#           lon  alt
# 0  +014:48:00  166
# 1  +015:37:00  160
# 2  +017:09:59  325
# 3  +015:31:59   93
# 4  +015:31:59   93
# Index(['station_id', 'name', 'CN', 'lat', 'lon', 'alt'], dtype='object')

# %%
import re

def dms_to_decimal_safe(dms_str):
    if isinstance(dms_str, float) or isinstance(dms_str, int):
        return float(dms_str)  # già convertito

    s = str(dms_str).strip()

    # match di tipo +44:17:43, -03:22:10, ecc.
    m = re.match(r"^([+-]?)(\d+):(\d+):(\d+(?:\.\d+)?)$", s)
    if not m:
        raise ValueError(f"Formato lat/lon non riconosciuto: {dms_str}")

    sign = -1 if m.group(1) == "-" else 1
    deg = float(m.group(2))
    minutes = float(m.group(3))
    seconds = float(m.group(4))

    return sign * (deg + minutes/60 + seconds/3600)

# %%
stations["lat"] = stations["lat"].apply(dms_to_decimal_safe)
stations["lon"] = stations["lon"].apply(dms_to_decimal_safe)
stations[["station_id", "lat", "lon"]].head()
# Out:
#   station_id        lat        lon
# 0     000001  56.866667  14.800000
# 1     000002  60.616667  15.616667
# 2     000003  65.066667  17.166389
# 3     000004  58.400000  15.533056
# 4     000005  58.400000  15.533056

# %%
def extract_era5_year_vectorized(ds_year, lat, lon):
    """
    Preleva la serie giornaliera t2m per un solo anno,
    usando nearest neighbour (velocissimo).
    """
    p = ds_year.t2m.sel(latitude=lat, longitude=lon, method="nearest")
    df = p.to_dataframe().reset_index()
    df = df.rename(columns={"valid_time": "date"})
    return df[["date", "t2m"]]

# %%
import random

# For slides: just 2022, a few stations
years_of_interest = [2022]

stations_sample = stations.sample(200, random_state=0).reset_index(drop=True)
print("Sample size:", len(stations_sample))

# Preload ERA5 (only 2022 now)
era5_cache = {}
for y in years_of_interest:
    print("Carico ERA5 per l'anno", y)
    era5_cache[y] = load_era5_tmax_year(y)

ndvi_cache = {}

def ndvi_month_cached(d, lat, lon):
    key = (d.year, d.month, round(lat,3), round(lon,3))
    if key not in ndvi_cache:
        # questa è la chiamata lenta: la facciamo una volta per (year,month,lat,lon)
        ndvi_cache[key] = sample_ndvi_at_point(d, lat, lon)
    return ndvi_cache[key]


def extract_era5_year_vectorized(ds_year, lat, lon):
    """
    Preleva la serie giornaliera t2m per un solo anno,
    usando nearest neighbour (veloce).
    """
    p = ds_year.t2m.sel(latitude=lat, longitude=lon, method="nearest")
    df = p.to_dataframe().reset_index()
    df = df.rename(columns={"valid_time": "date"})
    return df[["date", "t2m"]]


rows = []
used = 0
limit = 20  # <<< SOLO 3 STAZIONI PER ORA

for idx, row in stations_sample.iterrows():
    if used >= limit:
        break

    sid = row["station_id"]
    lat = float(row["lat"])
    lon = float(row["lon"])
    alt = row["alt"]

    print(f"\n=== Station {sid} ({idx+1}/{len(stations_sample)}) ===")

    # serie di stazione
    try:
        df_sta = load_station_tmax_series(sid)
    except FileNotFoundError:
        print("  File TX mancante, skip.")
        continue

    # solo anno 2022
    df_sta = df_sta[df_sta["date"].dt.year.isin(years_of_interest)]
    if df_sta.empty:
        print("  Nessun dato 2022, skip.")
        continue

    print("  Dati giornalieri dopo filtro:", len(df_sta))

    for year in df_sta["date"].dt.year.unique():
        ds_year = era5_cache[year]

        # ERA5 al punto (vectorizzato)
        df_era5 = extract_era5_year_vectorized(ds_year, lat, lon)

        # merge
        df_m = df_sta[df_sta["date"].dt.year == year].merge(
            df_era5, on="date", how="inner"
        )
        if df_m.empty:
            print("  Nessuna data in comune con ERA5 per", year)
            continue

        print("  Date in comune con ERA5 per", year, ":", len(df_m))

        # NDVI cached per mese
        df_m["ndvi_raw"] = [ndvi_month_cached(d, lat, lon) for d in df_m["date"]]

        df_m["station_id"] = sid
        df_m["lat"] = lat
        df_m["lon"] = lon
        df_m["alt"] = alt

        rows.append(df_m)

    used += 1
    print("  Stazione usata. Totale stazioni usate finora:", used)

# concat finale
if rows:
    df = pd.concat(rows, ignore_index=True)
    print("\nFinal shape df:", df.shape)
    display(df.head())
else:
    print("⚠️ Nessuna stazione con dati utili è stata trovata.")
# Out:
# Sample size: 200
# Carico ERA5 per l'anno 2022
# <xarray.Dataset> Size: 337MB
# Dimensions:     (valid_time: 365, latitude: 350, longitude: 660)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 3kB 2022-01-01 ... 2022-12-31
#   * latitude    (latitude) float64 3kB 69.9 69.8 69.7 69.6 ... 35.2 35.1 35.0
#   * longitude   (longitude) float64 5kB -25.0 -24.9 -24.8 ... 40.7 40.8 40.9
#     number      int64 8B ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 337MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-10-03T22:25 GRIB to CDM+CF via cfgrib-0.9.1...
#
# === Station 017818 (1/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 1
#
# === Station 001800 (2/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 2
#
# === Station 004477 (3/200) ===
#   Nessun dato 2022, skip.
#
# === Station 007034 (4/200) ===
#   Dati giornalieri dopo filtro: 322
#   Date in comune con ERA5 per 2022 : 322
#   Stazione usata. Totale stazioni usate finora: 3
#
# === Station 003965 (5/200) ===
#   Nessun dato 2022, skip.
#
# === Station 026983 (6/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 4
#
# === Station 007796 (7/200) ===
#   Nessun dato 2022, skip.
#
# === Station 003249 (8/200) ===
#   Nessun dato 2022, skip.
#
# === Station 024682 (9/200) ===
#   Dati giornalieri dopo filtro: 121
#   Date in comune con ERA5 per 2022 : 121
#   Stazione usata. Totale stazioni usate finora: 5
#
# === Station 024756 (10/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 6
#
# === Station 028058 (11/200) ===
#   Nessun dato 2022, skip.
#
# === Station 001614 (12/200) ===
#   Nessun dato 2022, skip.
#
# === Station 027007 (13/200) ===
#   Dati giornalieri dopo filtro: 361
#   Date in comune con ERA5 per 2022 : 361
#   Stazione usata. Totale stazioni usate finora: 7
#
# === Station 027513 (14/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 8
#
# === Station 004407 (15/200) ===
#   Dati giornalieri dopo filtro: 273
#   Date in comune con ERA5 per 2022 : 273
#   Stazione usata. Totale stazioni usate finora: 9
#
# === Station 027031 (16/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 10
#
# === Station 000617 (17/200) ===
#   Nessun dato 2022, skip.
#
# === Station 027735 (18/200) ===
#   Dati giornalieri dopo filtro: 352
#   Date in comune con ERA5 per 2022 : 352
#   Stazione usata. Totale stazioni usate finora: 11
#
# === Station 026639 (19/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 12
#
# === Station 004243 (20/200) ===
#   Nessun dato 2022, skip.
#
# === Station 000614 (21/200) ===
#   Nessun dato 2022, skip.
#
# === Station 025119 (22/200) ===
#   Nessun dato 2022, skip.
#
# === Station 024004 (23/200) ===
#   Nessun dato 2022, skip.
#
# === Station 024487 (24/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 13
#
# === Station 024405 (25/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 14
#
# === Station 007716 (26/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 15
#
# === Station 018245 (27/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 16
#
# === Station 002205 (28/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 17
#
# === Station 025878 (29/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 18
#
# === Station 027994 (30/200) ===
#   Nessun dato 2022, skip.
#
# === Station 024627 (31/200) ===
#   Dati giornalieri dopo filtro: 122
#   Date in comune con ERA5 per 2022 : 122
#   Stazione usata. Totale stazioni usate finora: 19
#
# === Station 005530 (32/200) ===
#   Dati giornalieri dopo filtro: 365
#   Date in comune con ERA5 per 2022 : 365
#   Stazione usata. Totale stazioni usate finora: 20
#
# Final shape df: (6661, 8)
#         date  t_station         t2m  ndvi_raw station_id        lat  \
# 0 2022-01-01       14.2  286.004791     168.0     017818  44.295278
# 1 2022-01-02       10.6  281.696045     168.0     017818  44.295278
# 2 2022-01-03        9.4  281.924500     168.0     017818  44.295278
# 3 2022-01-04        8.4  281.684998     168.0     017818  44.295278
# 4 2022-01-05        8.0  281.132141     168.0     017818  44.295278
#
#          lon   alt
# 0  10.428056  1150
# 1  10.428056  1150
# 2  10.428056  1150
# 3  10.428056  1150
# 4  10.428056  1150

# %%
df["t2m_c"] = df["t2m"] - 273.15
df["residual"] = df["t_station"] - df["t2m_c"]
df.head()
# Out:
#         date  t_station         t2m  ndvi_raw station_id        lat  \
# 0 2022-01-01       14.2  286.004791     168.0     017818  44.295278
# 1 2022-01-02       10.6  281.696045     168.0     017818  44.295278
# 2 2022-01-03        9.4  281.924500     168.0     017818  44.295278
# 3 2022-01-04        8.4  281.684998     168.0     017818  44.295278
# 4 2022-01-05        8.0  281.132141     168.0     017818  44.295278
#
#          lon   alt      t2m_c  residual
# 0  10.428056  1150  12.854797  1.345203
# 1  10.428056  1150   8.546051  2.053949
# 2  10.428056  1150   8.774506  0.625494
# 3  10.428056  1150   8.535004 -0.135004
# 4  10.428056  1150   7.982147  0.017853

# %%
df["ndvi"] = df["ndvi_raw"] / 255.0

# %%
import pandas as pd
'''
bins = [0, 0.2, 0.4, 0.6, 1.0]
labels = ["Bare/Low", "Sparse", "Moderate", "Dense"]

df["ndvi_class"] = pd.cut(df["ndvi"], bins=bins, labels=labels, include_lowest=True)
'''
bins = [0.55, 0.65, 0.75, 0.85, 1.0]
labels = ["0.55–0.65", "0.65–0.75", "0.75–0.85", "0.85–1.00"]

df["ndvi_class"] = pd.cut(df["ndvi"], bins=bins, labels=labels, include_lowest=True)

df.head()
# Out:
#         date  t_station         t2m  ndvi_raw station_id        lat  \
# 0 2022-01-01       14.2  286.004791     168.0     017818  44.295278
# 1 2022-01-02       10.6  281.696045     168.0     017818  44.295278
# 2 2022-01-03        9.4  281.924500     168.0     017818  44.295278
# 3 2022-01-04        8.4  281.684998     168.0     017818  44.295278
# 4 2022-01-05        8.0  281.132141     168.0     017818  44.295278
#
#          lon   alt      t2m_c  residual      ndvi ndvi_class
# 0  10.428056  1150  12.854797  1.345203  0.658824  0.65–0.75
# 1  10.428056  1150   8.546051  2.053949  0.658824  0.65–0.75
# 2  10.428056  1150   8.774506  0.625494  0.658824  0.65–0.75
# 3  10.428056  1150   8.535004 -0.135004  0.658824  0.65–0.75
# 4  10.428056  1150   7.982147  0.017853  0.658824  0.65–0.75

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="ndvi_class", y="residual")
plt.title("ERA5 bias by NDVI class (Station vs ERA5)")
plt.ylabel("Residual = T_station - ERA5 (°C)")
plt.xlabel("NDVI Class")
plt.grid(True, axis="y", alpha=0.3)
plt.show()

# %%
summary = df.groupby("ndvi_class")["residual"].agg(
    mean_bias="mean",
    std="std",
    rmse=lambda x: (x**2).mean()**0.5,
    count="count"
).round(2)

summary
# Out:
# /tmp/ipython-input-2211054719.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("ndvi_class")["residual"].agg(
#             mean_bias   std  rmse  count
# ndvi_class
# 0.55–0.65        1.04  3.57  3.71    576
# 0.65–0.75        1.74  2.43  2.99   1822
# 0.75–0.85        1.96  2.06  2.85   2175
# 0.85–1.00        2.31  2.03  3.08    947

# %%
df["month"] = df["date"].dt.month

plt.figure(figsize=(8,5))
sns.lineplot(data=df, x="month", y="residual", marker="o")
plt.title("Seasonal bias between station and ERA5")
plt.xlabel("Month")
plt.ylabel("Residual (°C)")
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import os

print(df.columns)

# 1) ERA5 da Kelvin a °C
df["t_era5_c"] = df["t2m"] - 273.15

# 2) NDVI da 0–255 a 0–1
print(df["ndvi_raw"].describe())  # abbiamo visto max ~231
df["ndvi"] = df["ndvi_raw"] / 255.0

# 3) Residuo stazione - ERA5
df["residual"] = df["t_station"] - df["t_era5_c"]

# 4) Stagione semplificata
month = df["date"].dt.month

df["season"] = np.select(
    [
        month.isin([12, 1, 2]),   # inverno
        month.isin([3, 4, 5]),    # primavera
        month.isin([6, 7, 8]),    # estate
        month.isin([9, 10, 11]),  # autunno
    ],
    ["winter", "spring", "summer", "autumn"],
    default="unknown"            # 👈 evita il TypeError
)

print(df["season"].value_counts())
'''
# 5) Salva per riuso
out_path = os.path.join(base_main, "master_era5_station_ndvi.parquet")
df.to_parquet(out_path)
print("Saved to:", out_path)
'''
df.head()
# Out:
# Index(['date', 't_station', 't2m', 'ndvi_raw', 'station_id', 'lat', 'lon',
#        'alt', 't2m_c', 'residual', 'ndvi', 'ndvi_class', 'month'],
#       dtype='object')
# count    6661.000000
# mean      181.842366
# std        33.994096
# min        49.000000
# 25%       166.000000
# 50%       185.000000
# 75%       203.000000
# max       235.000000
# Name: ndvi_raw, dtype: float64
# season
# autumn    1745
# spring    1656
# summer    1653
# winter    1607
# Name: count, dtype: int64
#         date  t_station         t2m  ndvi_raw station_id        lat  \
# 0 2022-01-01       14.2  286.004791     168.0     017818  44.295278
# 1 2022-01-02       10.6  281.696045     168.0     017818  44.295278
# 2 2022-01-03        9.4  281.924500     168.0     017818  44.295278
# 3 2022-01-04        8.4  281.684998     168.0     017818  44.295278
# 4 2022-01-05        8.0  281.132141     168.0     017818  44.295278
#
#          lon   alt      t2m_c  residual      ndvi ndvi_class  month  \
# 0  10.428056  1150  12.854797  1.345203  0.658824  0.65–0.75      1
# 1  10.428056  1150   8.546051  2.053949  0.658824  0.65–0.75      1
# 2  10.428056  1150   8.774506  0.625494  0.658824  0.65–0.75      1
# 3  10.428056  1150   8.535004 -0.135004  0.658824  0.65–0.75      1
# 4  10.428056  1150   7.982147  0.017853  0.658824  0.65–0.75      1
#
#     t_era5_c  season
# 0  12.854797  winter
# 1   8.546051  winter
# 2   8.774506  winter
# 3   8.535004  winter
# 4   7.982147  winter

# %%
df.groupby(pd.cut(df["ndvi"], bins=10))["residual"].mean()
# Out:
# /tmp/ipython-input-705068713.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df["ndvi"], bins=10))["residual"].mean()
# ndvi
# (0.191, 0.265]         NaN
# (0.265, 0.338]         NaN
# (0.338, 0.411]         NaN
# (0.411, 0.484]    1.373699
# (0.484, 0.557]    4.144131
# (0.557, 0.63]     3.040503
# (0.63, 0.703]     0.819935
# (0.703, 0.776]    2.219003
# (0.776, 0.849]    2.110005
# (0.849, 0.922]    2.309754
# Name: residual, dtype: float64

# %%
df.groupby("season")["residual"].agg(["mean", "std"])
# Out:
#             mean       std
# season
# autumn  1.633482  2.678892
# spring  2.197880  2.530888
# summer  2.533952  2.368161
# winter  1.542755  2.623828

# %%
df.groupby(pd.cut(df["lat"], bins=10))["residual"].mean()
df.groupby(pd.cut(df["alt"], bins=10))["residual"].mean()
# Out:
# /tmp/ipython-input-97676228.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df["lat"], bins=10))["residual"].mean()
# /tmp/ipython-input-97676228.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df["alt"], bins=10))["residual"].mean()
# alt
# (-1.43, 143.0]      3.226707
# (143.0, 286.0]      1.656038
# (286.0, 429.0]      1.663398
# (429.0, 572.0]      3.369833
# (572.0, 715.0]      2.356499
# (715.0, 858.0]           NaN
# (858.0, 1001.0]          NaN
# (1001.0, 1144.0]         NaN
# (1144.0, 1287.0]    0.332870
# (1287.0, 1430.0]   -1.124386
# Name: residual, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="t_era5_c", y="t_station", hue="ndvi", alpha=0.7)
plt.xlabel("ERA5 (°C)")
plt.ylabel("Station (°C)")
plt.title("ERA5 vs Station Temperature (colored by NDVI)")
plt.show()

# %%
sns.boxplot(data=df, x="season", y="residual")
# Out:
# <Axes: xlabel='season', ylabel='residual'>

# %% [markdown]
# Metrics

# %%
def summary_stats(x):
    x = x.dropna()
    mean = x.mean()
    std = x.std()
    rmse = np.sqrt((x**2).mean())
    mae = x.abs().mean()
    ci95 = 1.96 * std / np.sqrt(len(x))
    return pd.Series({
        "mean": mean,
        "std": std,
        "rmse": rmse,
        "mae": mae,
        "ci95": ci95,
        "n": len(x),
    })

global_stats = summary_stats(df["residual"])
print(global_stats)
# Out:
# mean       1.971650
# std        2.586752
# rmse       3.252317
# mae        2.528770
# ci95       0.065596
# n       5974.000000
# dtype: float64

# %%
'''
bins = [0.0, 0.2, 0.5, 1.0]
labels = ["low_veg (NDVI<0.2)", "mid_veg (0.2-0.5)", "high_veg (>0.5)"]
df["ndvi_class"] = pd.cut(df["ndvi"], bins=bins, labels=labels, include_lowest=True)
'''
df["ndvi_class"] = pd.qcut(df["ndvi"], q=3, labels=["low", "mid", "high"])


ndvi_stats = df.groupby("ndvi_class")["residual"].apply(summary_stats)
ndvi_stats
# Out:
# /tmp/ipython-input-808895601.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ndvi_stats = df.groupby("ndvi_class")["residual"].apply(summary_stats)
# ndvi_class
# low         mean       1.381769
#             std        3.463521
#             rmse       3.727955
#             mae        2.551057
#             ci95       0.171000
#             n       1576.000000
# mid         mean       2.127707
#             std        2.321645
#             rmse       3.148807
#             mae        2.547665
#             ci95       0.091690
#             n       2463.000000
# high        mean       2.253451
#             std        1.908057
#             rmse       2.952430
#             mae        2.486566
#             ci95       0.085017
#             n       1935.000000
# Name: residual, dtype: float64

# %%
season_stats = df.groupby("season")["residual"].apply(summary_stats)
season_stats
# Out:
# season
# autumn  mean       1.633482
#         std        2.678892
#         rmse       3.136899
#         mae        2.329435
#         ci95       0.132810
#         n       1563.000000
# spring  mean       2.197880
#         std        2.530888
#         rmse       3.351376
#         mae        2.638122
#         ci95       0.129293
#         n       1472.000000
# summer  mean       2.533952
#         std        2.368161
#         rmse       3.467749
#         mae        2.862726
#         ci95       0.121103
#         n       1469.000000
# winter  mean       1.542755
#         std        2.623828
#         rmse       3.043005
#         mae        2.297486
#         ci95       0.134132
#         n       1470.000000
# Name: residual, dtype: float64

# %%
# ad esempio soglia 250 m
df["alt_class"] = np.where(df["alt"] < 250, "low_alt (<250m)", "high_alt (>=250m)")
alt_stats = df.groupby("alt_class")["residual"].apply(summary_stats)
alt_stats
# Out:
# alt_class
# high_alt (>=250m)  mean       1.663018
#                    std        2.393057
#                    rmse       2.913842
#                    mae        2.394365
#                    ci95       0.084874
#                    n       3054.000000
# low_alt (<250m)    mean       2.294445
#                    std        2.738344
#                    rmse       3.572176
#                    mae        2.669342
#                    ci95       0.099324
#                    n       2920.000000
# Name: residual, dtype: float64

# %%
plt.figure(figsize=(7,5))

sns.boxplot(
    data=df,
    x="alt_class",
    y="residual",
    width=0.5,
    boxprops=dict(alpha=0.7),
    showfliers=True
)

plt.axhline(0, linestyle="--", color="#1f77b4", linewidth=1)

plt.title("Altitude Effect on ERA5 Bias", fontsize=14)
plt.xlabel("Altitude class")
plt.ylabel("Residual (T_station − ERA5)")

plt.show()

# %%
corr_vars = df[["residual", "ndvi", "alt", "lat", "lon"]].dropna()
corr_matrix = corr_vars.corr()
corr_matrix
# Out:
#           residual      ndvi       alt       lat       lon
# residual  1.000000  0.021892 -0.346701  0.110818 -0.204136
# ndvi      0.021892  1.000000 -0.119226 -0.344082 -0.209905
# alt      -0.346701 -0.119226  1.000000 -0.478777 -0.137180
# lat       0.110818 -0.344082 -0.478777  1.000000  0.379280
# lon      -0.204136 -0.209905 -0.137180  0.379280  1.000000

# %%
plt.figure(figsize=(6,4))
df.boxplot(column="residual", by="ndvi_class")
plt.axhline(0, linestyle="--")
plt.title("Station – ERA5 residuals by NDVI class")
plt.suptitle("")
plt.ylabel("Temperature difference (°C)")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.violinplot(data=df, x="ndvi_class", y="residual", cut=0)
plt.axhline(0, linestyle="--")
plt.ylabel("Temperature difference (°C)")
plt.xlabel("NDVI class")
plt.title("Residuals by NDVI class")
plt.show()

# %%
plt.figure(figsize=(4,4))
df_season = df[df["season"].isin(["summer","winter"])]
df_season.boxplot(column="residual", by="season")
plt.axhline(0, linestyle="--")
plt.title("Residuals by season")
plt.suptitle("")
plt.ylabel("Temperature difference (°C)")
plt.show()

# %%
df["coastal"] = np.where(df["lon"] < 0, "west/coastal-ish", "east/inland-ish")
coast_stats = df.groupby("coastal")["residual"].apply(summary_stats)
coast_stats
# Out:
# coastal
# east/inland-ish   mean       2.105484
#                   std        2.562982
#                   rmse       3.316715
#                   mae        2.556058
#                   ci95       0.071918
#                   n       4879.000000
# west/coastal-ish  mean       1.375324
#                   std        2.609096
#                   rmse       2.948335
#                   mae        2.407182
#                   ci95       0.154539
#                   n       1095.000000
# Name: residual, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# 1) Keep only rows without NaN in the main predictors
model_df = df[["residual", "ndvi", "alt", "lat", "lon", "season", "coastal"]].dropna()

X = model_df[["ndvi", "alt", "lat", "lon", "season", "coastal"]]
y = model_df["residual"]

numeric_features = ["ndvi", "alt", "lat", "lon"]
categorical_features = ["season", "coastal"]

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_features),
        ("cat", OneHotEncoder(drop="first"), categorical_features),
    ]
)

reg = Pipeline(
    steps=[
        ("preprocess", preprocess),
        ("model", LinearRegression())
    ]
)

reg.fit(X, y)

print("R^2:", reg.score(X, y))
coef = reg.named_steps["model"].coef_
intercept = reg.named_steps["model"].intercept_
print("Intercept:", intercept)
print("Coefs:", coef)
# Out:
# R^2: 0.3304967073543825
# Intercept: 3.9052535773657366
# Coefs: [-1.03685184e+00 -2.11610259e-03  3.85231429e-02 -1.94805498e-01
#   5.01229029e-01  9.02136962e-01 -1.78539788e-01 -3.29468699e+00]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Get the model you already trained
model = reg.named_steps["model"]
encoder = reg.named_steps["preprocess"]

# Build feature names (numeric + one-hot)
numeric_features = ["ndvi", "alt", "lat", "lon"]
categorical_features = ["season", "coastal"]

# Get one-hot names
ohe = encoder.named_transformers_["cat"]
ohe_features = ohe.get_feature_names_out(categorical_features).tolist()

feature_names = numeric_features + ohe_features

coefs = model.coef_

# sort by absolute importance
idx = np.argsort(np.abs(coefs))[::-1]

plt.figure(figsize=(6,5))
plt.barh(np.array(feature_names)[idx], np.abs(coefs)[idx])
plt.xlabel("Absolute coefficient")
plt.title("Feature Importance (Linear Model)")
plt.gca().invert_yaxis()
plt.show()

# %%
y_pred = reg.predict(X)

plt.figure(figsize=(5,5))
plt.scatter(y, y_pred, alpha=0.3)
plt.xlabel("Observed residual (°C)")
plt.ylabel("Predicted residual (°C)")
plt.title("Predicted vs Observed Residuals")
plt.axline((0,0),(1,1), color="red", linestyle="--")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# EXPLAINATORY MODELING

# %% [markdown]
# LINEAR REGRESSION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error

# -------------------------------------------------------------------
# 0. Prepare data used for the explanatory model
# -------------------------------------------------------------------

# Keep only rows with all needed columns
model_df = df[["residual", "ndvi", "alt", "lat", "lon", "season", "coastal"]].dropna()

X = model_df[["ndvi", "alt", "lat", "lon", "season", "coastal"]]
y = model_df["residual"].values

numeric_features = ["ndvi", "alt", "lat", "lon"]
categorical_features = ["season", "coastal"]

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_features),
        ("cat", OneHotEncoder(drop="first"), categorical_features),
    ]
)

linreg = LinearRegression()

model = Pipeline(steps=[
    ("preprocess", preprocess),
    ("regressor", linreg),
])

# Optional: train/test split just to check generalization
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

model.fit(X_train, y_train)

r2_train = model.score(X_train, y_train)
r2_test = model.score(X_test, y_test)

print(f"R² (train) = {r2_train:.3f}")
print(f"R² (test)  = {r2_test:.3f}")
# Out:
# R² (train) = 0.328
# R² (test)  = 0.338

# %%
# Refit on ALL data for the final correction model
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['ndvi', 'alt', 'lat',
#                                                    'lon']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['season', 'coastal'])])),
#                 ('regressor', LinearRegression())])

# %%
# -------------------------------------------------------------------
# 1. Inspect coefficients & build feature-importance barplot
# -------------------------------------------------------------------

# Get feature names after one-hot encoding
ohe = model.named_steps["preprocess"].named_transformers_["cat"]
cat_feature_names = ohe.get_feature_names_out(categorical_features)

feature_names = numeric_features + list(cat_feature_names)
coefs = model.named_steps["regressor"].coef_

coef_df = pd.DataFrame({
    "feature": feature_names,
    "coef": coefs,
    "abs_coef": np.abs(coefs),
}).sort_values("abs_coef", ascending=False)

print("\nLinear model coefficients:")
print(coef_df[["feature", "coef"]])

# Feature-importance plot (absolute coefficients)
plt.figure(figsize=(7, 5))
sns.barplot(
    data=coef_df,
    x="abs_coef",
    y="feature",
    orient="h"
)
plt.xlabel("Absolute coefficient")
plt.ylabel("")
plt.title("Feature Importance (Linear Model)")
plt.tight_layout()
plt.show()
# Out:
# Linear model coefficients:
#                     feature      coef
# 7  coastal_west/coastal-ish -3.294687
# 0                      ndvi -1.036852
# 5             season_summer  0.902137
# 4             season_spring  0.501229
# 3                       lon -0.194805
# 6             season_winter -0.178540
# 2                       lat  0.038523
# 1                       alt -0.002116

# %%
# -------------------------------------------------------------------
# 2. Predict residuals and build corrected ERA5 temperature
# -------------------------------------------------------------------

y_pred = model.predict(X)  # predicted bias/residual

# Attach predictions back to model_df index
model_df = model_df.copy()
model_df["pred_residual"] = y_pred

# New residual after correction: true_residual - predicted_residual
model_df["residual_corrected"] = model_df["residual"] - model_df["pred_residual"]

# Decide which column is ERA5 temperature
era5_candidates = ["t_era5_c", "t2m_c", "t_era5", "t2m"]
era5_cols_present = [c for c in era5_candidates if c in df.columns]
if not era5_cols_present:
    raise ValueError("No ERA5 temperature column found in df.")
era5_col = era5_cols_present[0]
print(f"Using ERA5 column: {era5_col}")

# Build corrected ERA5 temperature
model_df["t_era5_corrected"] = df.loc[model_df.index, era5_col] + model_df["pred_residual"]

# (Optional) check a few rows
display(
    model_df[["residual", "pred_residual", "residual_corrected"]].head()
)
# Out:
# Using ERA5 column: t_era5_c
#    residual  pred_residual  residual_corrected
# 0  1.345203       0.285044            1.060158
# 1  2.053949       0.285044            1.768905
# 2  0.625494       0.285044            0.340450
# 3 -0.135004       0.285044           -0.420048
# 4  0.017853       0.285044           -0.267191

# %%
# -------------------------------------------------------------------
# 3. Metrics BEFORE vs AFTER correction
# -------------------------------------------------------------------

def metrics_from_residual(res):
    res = np.asarray(res)
    mean_bias = res.mean()
    std = res.std(ddof=1)
    rmse = np.sqrt(mean_squared_error(np.zeros_like(res), res))
    mae = mean_absolute_error(np.zeros_like(res), res)
    return mean_bias, std, rmse, mae

mean_before, std_before, rmse_before, mae_before = metrics_from_residual(model_df["residual"])
mean_after, std_after, rmse_after, mae_after = metrics_from_residual(model_df["residual_corrected"])

summary_metrics = pd.DataFrame({
    "mean_bias": [mean_before, mean_after],
    "std": [std_before, std_after],
    "rmse": [rmse_before, rmse_after],
    "mae": [mae_before, mae_after],
}, index=["Original (ERA5)", "Corrected (ERA5 + model)"])

print("\nMetrics before vs after correction:")
print(summary_metrics.round(3))
# Out:
# Metrics before vs after correction:
#                           mean_bias    std   rmse    mae
# Original (ERA5)               1.972  2.587  3.252  2.529
# Corrected (ERA5 + model)      0.000  2.117  2.116  1.602

# %%
# -------------------------------------------------------------------
# 4. Plots for Period 4
# -------------------------------------------------------------------

# 4a) Predicted vs observed residuals (for slide D)
plt.figure(figsize=(6, 6))
plt.scatter(model_df["residual"], model_df["pred_residual"], alpha=0.3, edgecolor="none")
lims = [
    min(model_df["residual"].min(), model_df["pred_residual"].min()),
    max(model_df["residual"].max(), model_df["pred_residual"].max()),
]
plt.plot(lims, lims, "r--")  # 1:1 line
plt.xlabel("Observed residual (°C)")
plt.ylabel("Predicted residual (°C)")
plt.title("Predicted vs Observed Residuals")
plt.tight_layout()
plt.show()

# 4b) Histogram of residuals BEFORE vs AFTER (for correction slide)
plt.figure(figsize=(7, 5))
sns.histplot(model_df["residual"], bins=40, alpha=0.4, label="Original residual")
sns.histplot(model_df["residual_corrected"], bins=40, alpha=0.4, label="Corrected residual")
plt.xlabel("Residual (T_station − ERA5) [°C]")
plt.ylabel("Count")
plt.title("Residual Distribution Before vs After Correction")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# -------------------------------------------------------------------
# 5. Small example table for slides (few stations / dates)
# -------------------------------------------------------------------

# Columns coming from the original df
id_date_cols = [c for c in ["station_id", "date"] if c in df.columns]

# Temperature columns from df
temp_cols = [c for c in ["t_station", era5_col] if c in df.columns]

# Model-related columns from model_df
model_cols = ["residual", "pred_residual", "residual_corrected"]

# Start from df (to get station_id/date/temps) but only for rows in model_df
base = df.loc[model_df.index, id_date_cols + temp_cols].copy()

# Attach model outputs
base[model_cols] = model_df[model_cols]

# Build corrected ERA5 temp
base["t_era5_corrected"] = base[era5_col] + base["pred_residual"]

# Final column order for the slide
example_cols = id_date_cols + [
    "t_station",
    era5_col,
    "residual",
    "pred_residual",
    "residual_corrected",
    "t_era5_corrected",
]

example_cols = [c for c in example_cols if c in base.columns]

example_df = base[example_cols].head(6)

print("\nExample rows for slide table:")
display(example_df.round(2))
# Out:
# Example rows for slide table:
#   station_id       date  t_station  t_era5_c  residual  pred_residual  \
# 0     017818 2022-01-01       14.2     12.85      1.35           0.29
# 1     017818 2022-01-02       10.6      8.55      2.05           0.29
# 2     017818 2022-01-03        9.4      8.77      0.63           0.29
# 3     017818 2022-01-04        8.4      8.54     -0.14           0.29
# 4     017818 2022-01-05        8.0      7.98      0.02           0.29
# 5     017818 2022-01-06       -0.2      1.09     -1.29           0.29
#
#    residual_corrected  t_era5_corrected
# 0                1.06             13.14
# 1                1.77              8.83
# 2                0.34              9.06
# 3               -0.42              8.82
# 4               -0.27              8.27
# 5               -1.57              1.37

# %% [markdown]
# HistGradientBoosting Regressor

# %%
import pandas as pd
import numpy as np

# Select columns (must be cleaned beforehand)
model_df = df[[
    "residual", "ndvi", "alt", "lat", "lon", "season", "coastal"
]].dropna()

# X and y
X = model_df[["ndvi", "alt", "lat", "lon", "season", "coastal"]]
y = model_df["residual"]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import train_test_split

# One-hot encode season + coastal
ct = ColumnTransformer(
    transformers=[
        ("onehot", OneHotEncoder(drop="first"), ["season", "coastal"])
    ],
    remainder="passthrough"
)

gb = HistGradientBoostingRegressor(
    learning_rate=0.05,
    max_depth=4,
    max_iter=300,
    l2_regularization=0.1,
    random_state=0
)

model = Pipeline([
    ("prep", ct),
    ("gb", gb)
])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehot',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['season', 'coastal'])])),
#                 ('gb',
#                  HistGradientBoostingRegressor(l2_regularization=0.1,
#                                                learning_rate=0.05, max_depth=4,
#                                                max_iter=300, random_state=0))])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

print("R² (train) =", r2_score(y_train, y_pred_train))
print("R² (test)  =", r2_score(y_test, y_pred_test))
# Out:
# R² (train) = 0.6028204890365698
# R² (test)  = 0.5741936400915278

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

print("R² (train) =", r2_score(y_train, y_pred_train))
print("R² (test)  =", r2_score(y_test, y_pred_test))
# Out:
# R² (train) = 0.6028204890365698
# R² (test)  = 0.5741936400915278

# %%
# 1) Predict only on the non-NaN rows used in the model
y_pred_full = model.predict(X)   # length = len(model_df)

# 2) Write them back to the corresponding rows in df
df.loc[model_df.index, "pred_residual"] = y_pred_full

# 3) Compute corrected residual only on those rows
df.loc[model_df.index, "residual_corrected"] = (
    df.loc[model_df.index, "residual"] - df.loc[model_df.index, "pred_residual"]
)

# 4) Corrected ERA5 temperature
df.loc[model_df.index, "t_era5_corrected"] = (
    df.loc[model_df.index, "t_era5_c"] + df.loc[model_df.index, "pred_residual"]
)

# %%
def metrics(x):
    x = x.dropna()
    return pd.Series({
        "mean_bias": x.mean(),
        "std": x.std(),
        "rmse": np.sqrt((x**2).mean()),
        "mae": x.abs().mean()
    })

results_before = metrics(df["residual"])
results_after  = metrics(df["residual_corrected"])

comparison = pd.DataFrame({
    "ERA5_raw": results_before,
    "ERA5_corrected": results_after
})
print(comparison.round(3))
# Out:
#            ERA5_raw  ERA5_corrected
# mean_bias     1.972           0.004
# std           2.587           1.641
# rmse          3.252           1.641
# mae           2.529           1.205

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
sns.kdeplot(df["residual"], label="Original ERA5 residual", linewidth=2)
sns.kdeplot(df["residual_corrected"], label="Corrected residual", linewidth=2)
plt.axvline(0, color="black", linestyle="--")
plt.title("Residual distribution before/after correction")
plt.legend()
plt.show()

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    model, X_test, y_test,
    n_repeats=10,
    random_state=0,
    n_jobs=-1
)

# Feature names = original columns of X_test
feature_names = X_test.columns

fi = pd.DataFrame({
    "feature": feature_names,
    "importance": result.importances_mean
}).sort_values("importance", ascending=False)

print(fi)
# Out:
#    feature  importance
# 1      alt    0.629431
# 3      lon    0.130538
# 0     ndvi    0.108591
# 4   season    0.069470
# 2      lat    0.022536
# 5  coastal    0.019015

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.barh(fi["feature"], fi["importance"])
plt.gca().invert_yaxis()
plt.xlabel("Permutation importance")
plt.title("Which factors explain ERA5 bias?")
plt.tight_layout()
plt.show()

# %%
fi_plot = fi.head(10)   # top 10 most important features
fi_plot
# Out:
#    feature  importance
# 1      alt    0.629431
# 3      lon    0.130538
# 0     ndvi    0.108591
# 4   season    0.069470
# 2      lat    0.022536
# 5  coastal    0.019015

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.barh(fi["feature"], fi["importance"])
plt.gca().invert_yaxis()
plt.title("Permutation Importance (HistGradientBoostingRegressor)")
plt.show()

# %%
from sklearn.inspection import PartialDependenceDisplay
PartialDependenceDisplay.from_estimator(
    model, X_test,
    features=["ndvi","alt","lat","lon"],
    kind="average"
)

# %%
from sklearn.inspection import PartialDependenceDisplay

fig, ax = plt.subplots(1, 2, figsize=(10,4))
PartialDependenceDisplay.from_estimator(model, X, ["ndvi"], ax=ax[0])
PartialDependenceDisplay.from_estimator(model, X, ["alt"], ax=ax[1])

ax[0].set_title("PDP: Effect of NDVI on residual")
ax[1].set_title("PDP: Effect of altitude on residual")
plt.tight_layout()
plt.show()

# %% [markdown]
# CUSTOMED MODEL

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# ======================================================
# 0. START FROM YOUR GLOBAL df
#    df must have: t_station, t2m, ndvi, alt, lat, lon, season, coastal, station_id
# ======================================================

# 1) ERA5 in °C and residual (same as before)
df["t_era5_c"] = df["t2m"] - 273.15
df["residual"] = df["t_station"] - df["t_era5_c"]

# Keep only the rows we can actually use
required_cols = ["t_station", "t2m", "t_era5_c", "ndvi", "alt", "lat", "lon",
                 "season", "coastal", "station_id", "residual"]
df_model = df[required_cols].dropna().copy()

print("Total usable samples:", len(df_model))

# ======================================================
# 1. PHYSICS-INFORMED FEATURE ENGINEERING
# ======================================================

# NDVI^2 to let the model learn saturation / non-linearity
df_model["ndvi2"] = df_model["ndvi"] ** 2

# Simple lapse-rate proxy (altitude in hundreds of meters)
df_model["alt_lapse"] = df_model["alt"] / 150.0

# UHI proxy: low NDVI + southern France (lat < 47)
df_model["uhi_proxy"] = (1 - df_model["ndvi"]) * (df_model["lat"] < 47).astype(int)

# Coastal × latitude interaction (stronger coastal effects in north)
# If coastal is string (east/inland-ish vs west/coastal-ish), we leave it for one-hot.
# Here we build a numeric interaction using a binary coastal flag:
if df_model["coastal"].dtype == "O":
    coastal_flag = df_model["coastal"].map({"east/inland-ish": 0, "west/coastal-ish": 1})
else:
    coastal_flag = df_model["coastal"].astype(int)

df_model["coast_interaction"] = coastal_flag * (df_model["lat"] > 47).astype(int)

# ======================================================
# 2. BUILD X, y WITH ALL FEATURES
#    (season & coastal will be one-hot encoded by ColumnTransformer)
# ======================================================

feature_cols = [
    # will be one-hot encoded:
    "season",
    "coastal",
    # numeric / physics-informed:
    "t_era5_c",
    "ndvi",
    "ndvi2",
    "alt",
    "alt_lapse",
    "lat",
    "lon",
    "uhi_proxy",
    "coast_interaction",
]

X = df_model[feature_cols].copy()
y = df_model["residual"].copy()

print("Feature columns:", list(X.columns))

# ======================================================
# 3. SAME SPLIT LOGIC AS YOUR EXISTING CODE
#    (test_size=0.2, random_state=0)
# ======================================================

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

print("Train size:", len(X_train), "Test size:", len(X_test))

# ======================================================
# 4. COLUMNTRANSFORMER + HISTGRADIENTBOOSTING (CUSTOM MODEL)
# ======================================================

ct = ColumnTransformer(
    transformers=[
        ("onehot", OneHotEncoder(drop="first"), ["season", "coastal"]),
    ],
    remainder="passthrough",  # keeps numeric physics features
)

gb = HistGradientBoostingRegressor(
    learning_rate=0.05,
    max_depth=4,
    max_iter=400,
    l2_regularization=0.1,
    random_state=0
)

phys_model = Pipeline([
    ("prep", ct),
    ("gb", gb)
])

# Fit
phys_model.fit(X_train, y_train)

# Predict residuals
y_pred_train = phys_model.predict(X_train)
y_pred_test  = phys_model.predict(X_test)

print("\nR² (train) =", r2_score(y_train, y_pred_train))
print("R² (test)  =", r2_score(y_test, y_pred_test))

# ======================================================
# 5. METRICS BEFORE VS AFTER CORRECTION ON TEST SET
# ======================================================

def stats_from_residual(res):
    res = pd.Series(res).dropna()
    mean_bias = res.mean()
    std = res.std()
    rmse = np.sqrt((res ** 2).mean())
    mae = res.abs().mean()
    return pd.Series(
        {"mean_bias": mean_bias, "std": std, "rmse": rmse, "mae": mae}
    )

# Original residuals on test set (ERA5 only)
res_orig_test = y_test

# Corrected residuals: subtract predicted residual
res_corr_test = y_test - y_pred_test

metrics_table = pd.DataFrame({
    "ERA5_raw": stats_from_residual(res_orig_test),
    "ERA5_corrected": stats_from_residual(res_corr_test),
}).round(3)

print("\nMetrics before vs after correction (TEST SET):")
print(metrics_table)

# ======================================================
# 6. OPTIONAL: EXAMPLE ROWS FOR SLIDES
# ======================================================

# we need the subset of df_model that corresponds to X_test
test_idx = X_test.index

t_era5_test = df_model.loc[test_idx, "t_era5_c"]
t_corr_test = t_era5_test + y_pred_test

example_rows = pd.DataFrame({
    "station_id": df_model.loc[test_idx, "station_id"].head(5),
    "t_station": df_model.loc[test_idx, "t_station"].head(5).round(2),
    "t_era5_c": t_era5_test.head(5).round(2),
    "residual": res_orig_test.head(5).round(2),
    "pred_residual": pd.Series(y_pred_test, index=test_idx).head(5).round(2),
    "residual_corrected": res_corr_test.head(5).round(2),
    "t_era5_corrected": t_corr_test.head(5).round(2),
})

print("\nExample rows for slide table:")
print(example_rows)
# Out:
# Total usable samples: 5974
# Feature columns: ['season', 'coastal', 't_era5_c', 'ndvi', 'ndvi2', 'alt', 'alt_lapse', 'lat', 'lon', 'uhi_proxy', 'coast_interaction']
# Train size: 4779 Test size: 1195
#
# R² (train) = 0.6724281077136727
# R² (test)  = 0.5967160511100369
#
# Metrics before vs after correction (TEST SET):
#            ERA5_raw  ERA5_corrected
# mean_bias     2.024           0.002
# std           2.532           1.608
# rmse          3.241           1.607
# mae           2.576           1.202
#
# Example rows for slide table:
#      station_id  t_station   t_era5_c  residual  pred_residual  \
# 144      017818       21.5  19.850000      1.65           1.47
# 4915     007716       24.1  24.190001     -0.09           0.54
# 2574     027513       16.5  16.500000      0.00          -0.55
# 202      017818       32.3  30.010000      2.29           0.92
# 5965     025878       33.5  29.580000      3.92           3.24
#
#       residual_corrected  t_era5_corrected
# 144                 0.18             21.32
# 4915               -0.63             24.73
# 2574                0.55             15.95
# 202                 1.37             30.93
# 5965                0.68             32.82

# %% [markdown]
# XG boost CUSTOM MODEL

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# ------------------------------
# 1. Build model_df
# ------------------------------
model_df = df[["residual", "ndvi", "alt", "lat", "lon", "season", "coastal"]].dropna().copy()

# ------------------------------
# 2. Physical feature engineering
# ------------------------------

eps = 1e-3
model_df["ndvi2"] = model_df["ndvi"]**2
model_df["inv_ndvi"] = 1 / (model_df["ndvi"] + eps)

model_df["alt2"] = model_df["alt"]**2
model_df["inv_alt"] = 1 / (model_df["alt"] + eps)

model_df["is_summer"] = model_df["season"].isin(["summer"]).astype(int)

model_df["ndvi_summer"] = model_df["ndvi"] * model_df["is_summer"]
model_df["alt_summer"] = model_df["alt"] * model_df["is_summer"]

# ------------------------------
# 3. Prepare X, y
# ------------------------------

X = model_df[[
    "ndvi", "ndvi2", "inv_ndvi",
    "alt", "alt2", "inv_alt",
    "lat", "lon",
    "season", "coastal",
    "is_summer",
    "ndvi_summer", "alt_summer"
]]

# one-hot encode season + coastal
X = pd.get_dummies(X, columns=["season", "coastal"], drop_first=True)

y = model_df["residual"]

# ------------------------------
# 4. Train-test split
# ------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

# ------------------------------
# 5. Monotonic constraints
# ------------------------------
# residual increases:
#   when ndvi decreases → monotonic -1
#   when alt decreases → monotonic -1

# constraint list must match the number of features
constraints = []
for col in X.columns:
    if col in ["ndvi", "ndvi2", "inv_ndvi"]:
        constraints.append(-1)  # lower NDVI → higher residual
    elif col in ["alt", "alt2", "inv_alt"]:
        constraints.append(-1)  # lower altitude → higher residual
    else:
        constraints.append(0)   # no constraint

# ------------------------------
# 6. XGBoost model
# ------------------------------
model = XGBRegressor(
    n_estimators=400,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.7,
    colsample_bytree=0.8,
    tree_method="hist",
    monotone_constraints=tuple(constraints),
    objective="reg:squarederror",
    random_state=0
)

model.fit(X_train, y_train)

# ------------------------------
# 7. Evaluate
# ------------------------------
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

print("R² (train):", r2_score(y_train, y_pred_train))
print("R² (test):", r2_score(y_test, y_pred_test))
print("\nRMSE test:", np.sqrt(mean_squared_error(y_test, y_pred_test)))
print("MAE test:", mean_absolute_error(y_test, y_pred_test))
# Out:
# R² (train): 0.6028606680928484
# R² (test): 0.5738788240766207
#
# RMSE test: 1.6522968039093588
# MAE test: 1.2567500684089241

# %%
# Heatmap of ERA5 error across France
plt.figure(figsize=(8,6))
plt.scatter(df.lon, df.lat, c=df.residual, cmap='coolwarm', s=8)
plt.colorbar(label="Residual (°C)")
plt.title("Spatial Structure of ERA5 Bias Across Stations")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
#Partial Dependence Plots
from sklearn.inspection import PartialDependenceDisplay

PartialDependenceDisplay.from_estimator(
    model,
    X_train,
    features=["ndvi", "alt"],
    kind="average"
)
plt.show()
